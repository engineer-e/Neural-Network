# %% [markdown]
# # Network Architecture
#
# 1. Commonly one neuron, even with many inputs, may not be sufficient.
# 2. We might need five or ten, operating in parallel, in what we will call a "layer."
# 3. This concept of a layer is discussed below.
#
# - [A Layer of Neurons](a_layer_of_neurons.ipynb)
# - [Multiple Layers of Neurons](multiple_layers_of_neurons.ipynb)
# - [Recurrent Networks](recurrent_networks.ipynb)

# %% [markdown]
# # How to Pick an Architecture

# %% [markdown]
# Problem specifications helps define the network in the following ways:
#
# 1. Number of network inputs = number of problem inputs
# 2. Number of neurons in output layer = number of problem outputs
# 3. Output layer transfer function choice at least partly determined by problem specification of the outputs.
