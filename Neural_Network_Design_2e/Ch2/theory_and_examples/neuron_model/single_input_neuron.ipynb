# %% [markdown]
# # Neuron Model
#
# ## Single-Input Neuron
#
#
# > Weight, Bias, Net Input, Transfer Function
#
# 1. The scalar input _p_ is multiplied by the scalar weight _w_ to form _wp_, one of terms that is sent to the summar.
# 2. The other input, 1, is multiplied by a _bias b_ and then passed to the summer.
# 3. The Summer output _n_, often referred to as the _net input_, goes into a _transfer function f_, which produces the scalar neuron output _a_.
# 4. Some authors use the term
#    - "activation function" rather than _transfer function_
#    - "offset" rather than _bias_
# 5. This simple model back to the biological neuron that we discussed in _Chatper 1_
# 6. The weight _w_ corresponds to the strength of a synapse.
# 7. The Cell body is represented by the summation and the transfer function, and the neuron output _a_ represents the signal on the axon

# %% [markdown]
# $$\displaystyle a = f(wp+b)$$

# %%
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output


# ============================================================
# TRANSFER FUNCTION
# ============================================================

def f(n):
    return n


# ============================================================
# DRAW NEURON
# ============================================================

def show_neuron(p, w, b):

    # Neuron calculation
    n = w * p + b
    a = f(n)

    html = f"""
    <div style="
        width:900px;
        margin:10px auto;
        padding:25px;
        background:#F5F7FA;
        border-radius:15px;
        font-family:Arial;
    ">

        <h2 style="
            text-align:center;
            color:#17202A;
        ">
            Single-Input Neuron
        </h2>

        <svg
            width="850"
            height="430"
            viewBox="0 0 850 430"
            xmlns="http://www.w3.org/2000/svg">

            <!-- INPUT -->

            <circle
                cx="60"
                cy="170"
                r="9"
                fill="#2874A6"/>

            <text
                x="25"
                y="130"
                font-size="19"
                font-weight="bold"
                fill="#2874A6">
                Input
            </text>

            <text
                x="25"
                y="210"
                font-size="23"
                fill="#2874A6">
                p = {p:.1f}
            </text>


            <!-- INPUT ARROW -->

            <line
                x1="70"
                y1="170"
                x2="190"
                y2="170"
                stroke="#2874A6"
                stroke-width="4"/>

            <polygon
                points="190,170 175,162 175,178"
                fill="#2874A6"/>


            <!-- WEIGHT -->

            <text
                x="115"
                y="145"
                font-size="22"
                fill="#8E44AD">
                w = {w:.1f}
            </text>


            <!-- SUMMATION -->

            <rect
                x="190"
                y="120"
                width="95"
                height="100"
                rx="10"
                fill="white"
                stroke="#2C3E50"
                stroke-width="4"/>

            <text
                x="237"
                y="190"
                text-anchor="middle"
                font-size="45"
                fill="#2C3E50">
                Σ
            </text>


            <!-- BIAS -->

            <line
                x1="237"
                y1="330"
                x2="237"
                y2="220"
                stroke="#E67E22"
                stroke-width="4"/>

            <polygon
                points="237,220 229,235 245,235"
                fill="#E67E22"/>

            <text
                x="260"
                y="305"
                font-size="22"
                fill="#E67E22">
                b = {b:.1f}
            </text>


            <!-- n -->

            <line
                x1="285"
                y1="170"
                x2="420"
                y2="170"
                stroke="#34495E"
                stroke-width="4"/>

            <polygon
                points="420,170 405,162 405,178"
                fill="#34495E"/>

            <text
                x="335"
                y="145"
                font-size="22"
                fill="#34495E">
                n = {n:.2f}
            </text>


            <!-- TRANSFER FUNCTION -->

            <rect
                x="420"
                y="120"
                width="100"
                height="100"
                rx="10"
                fill="#EAF8F0"
                stroke="#27AE60"
                stroke-width="4"/>

            <text
                x="470"
                y="190"
                text-anchor="middle"
                font-size="45"
                fill="#27AE60">
                f
            </text>


            <!-- OUTPUT -->

            <line
                x1="520"
                y1="170"
                x2="665"
                y2="170"
                stroke="#C0392B"
                stroke-width="4"/>

            <polygon
                points="665,170 650,162 650,178"
                fill="#C0392B"/>

            <text
                x="755"
                y="180"
                text-anchor="middle"
                font-size="25"
                font-weight="bold"
                fill="#C0392B">
                a = {a:.2f}
            </text>


            <!-- EQUATION -->

            <text
                x="425"
                y="380"
                text-anchor="middle"
                font-size="25"
                fill="#17202A">
                a = f(wp + b) = f(n)
            </text>

        </svg>


        <!-- CALCULATION -->

        <div style="
            background:white;
            padding:18px;
            border-radius:10px;
            font-size:18px;
        ">

            <b style="color:#2C3E50;">
                Live Calculation
            </b>

            <br><br>

            <span style="color:#2874A6;">
                p = {p:.2f}
            </span>

            <br>

            <span style="color:#8E44AD;">
                w = {w:.2f}
            </span>

            <br>

            <span style="color:#E67E22;">
                b = {b:.2f}
            </span>

            <br><br>

            <span style="color:#34495E;">
                n = wp + b
            </span>

            <br>

            n = ({w:.2f})({p:.2f}) + ({b:.2f})

            <br>

            n = <b>{n:.2f}</b>

            <br><br>

            <span style="color:#27AE60;">
                a = f(n) = f({n:.2f}) = 
                <b>{a:.2f}</b>
            </span>

        </div>

    </div>
    """

    display(HTML(html))


# ============================================================
# PYTHON SLIDERS
# ============================================================

p_slider = widgets.FloatSlider(
    value=2.0,
    min=-5.0,
    max=5.0,
    step=0.1,
    description="Input p:",
    continuous_update=True,
    readout=True,
    readout_format=".1f",
    style={"description_width": "80px"},
    layout=widgets.Layout(width="450px")
)

w_slider = widgets.FloatSlider(
    value=3.0,
    min=-5.0,
    max=5.0,
    step=0.1,
    description="Weight w:",
    continuous_update=True,
    readout=True,
    readout_format=".1f",
    style={"description_width": "80px"},
    layout=widgets.Layout(width="450px")
)

b_slider = widgets.FloatSlider(
    value=1.0,
    min=-5.0,
    max=5.0,
    step=0.1,
    description="Bias b:",
    continuous_update=True,
    readout=True,
    readout_format=".1f",
    style={"description_width": "80px"},
    layout=widgets.Layout(width="450px")
)


# ============================================================
# OUTPUT
# ============================================================

output = widgets.interactive_output(
    show_neuron,
    {
        "p": p_slider,
        "w": w_slider,
        "b": b_slider
    }
)


# ============================================================
# DISPLAY
# ============================================================

controls = widgets.VBox([
    widgets.HTML(
        "<h3 style='color:#2C3E50;'>Neuron Controls</h3>"
    ),
    p_slider,
    w_slider,
    b_slider
])

display(
    widgets.VBox([
        controls,
        output
    ])
)
# Out:
# VBox(children=(VBox(children=(HTML(value="<h3 style='color:#2C3E50;'>Neuron Controls</h3>"), FloatSlider(value…

# %% [markdown]
# 8. The actual output depends on the particular transfer function that is chosen.
# 9. We will discuss transfer function in the next section
# 10. The bias is much like a weight, except that it has a constant input of 1.
# 11. However, if you do not want to have a bias in a particular neuron, it can be omitted. We will see examples of this in Chapter 3, 7 and 16
# 12. **Note :** *w* and *b* are both *adjustable* scalar parameters of the neurons.
# 13. Typically the *Transfer function* is chosen by the designer and then the parameters *w* and *b* will be adjusted by some learning rule
# 14. So that the neuron input/output relationship meets some specific goal (see Chapter 4 for an introduction to learning rules).
# 15. As described in the following section, we have different transfer functions for different purposes.
