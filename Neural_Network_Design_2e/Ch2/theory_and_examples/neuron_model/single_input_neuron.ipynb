# %% [markdown]
# # Neuron Model
#
# ## Single-Input Neuron
#
#
# > Weight, Bias, Net Input, Transfer Function
#
# 1. The scalar input _p_ is multiplied by the scalar weight _w_ to form _wp_, one of terms that is sent to the summar.
# 2. The other input, 1, is multiplied by a _bias b_ and then passed to the summer.
# 3. The Summer output _n_, often referred to as the _net input_, goes into a _transfer function f_, which produces the scalar neuron output _a_.
# 4. Some authors use the term
#    - "activation function" rather than _transfer function_
#    - "offset" rather than _bias_
# 5. This simple model back to the biological neuron that we discussed in _Chatper 1_
# 6. The weight _w_ corresponds to the strength of a synapse.
# 7. The Cell body is represented by the summation and the transfer function, and the neuron output _a_ represents the signal on the axon

# %% [markdown]
# $$\displaystyle a = f(wp+b)$$

# %%
from IPython.display import HTML, display

display(HTML("""
<style>
.neuron-box {
    font-family: Arial, sans-serif;
    max-width: 1000px;
    margin: auto;
    padding: 25px;
    background: #f5f7fa;
    border-radius: 15px;
}

.neuron-title {
    text-align: center;
    font-size: 28px;
    font-weight: bold;
    color: #17202a;
    margin-bottom: 25px;
}

.neuron-layout {
    display: flex;
    gap: 30px;
    align-items: center;
    justify-content: center;
}

.diagram {
    background: white;
    border-radius: 15px;
    padding: 10px;
    box-shadow: 0 3px 12px #cccccc;
}

.controls {
    background: white;
    padding: 20px;
    border-radius: 15px;
    box-shadow: 0 3px 12px #cccccc;
    width: 300px;
}

.control {
    margin: 18px 0;
}

.control label {
    display: block;
    font-weight: bold;
    margin-bottom: 6px;
}

.control input[type="range"] {
    width: 200px;
}

.value {
    display: inline-block;
    width: 55px;
    text-align: center;
    font-weight: bold;
}

.calculation {
    margin-top: 20px;
    padding: 15px;
    background: #eef2f7;
    border-radius: 10px;
    line-height: 1.8;
    font-size: 17px;
}
</style>


<div class="neuron-box">

<div class="neuron-title">
    Single-Input Neuron
</div>

<div class="neuron-layout">

<!-- ================= DIAGRAM ================= -->

<div class="diagram">

<svg width="600" height="350" viewBox="0 0 600 350">

    <!-- Input -->
    <circle cx="55" cy="160" r="8"
            fill="#2874A6"/>

    <text x="30" y="125"
          font-size="18"
          font-weight="bold"
          fill="#2874A6">
        Input
    </text>

    <text x="42" y="195"
          font-size="25"
          fill="#2874A6">
        p
    </text>

    <!-- Arrow p -->
    <line x1="65" y1="160"
          x2="175" y2="160"
          stroke="#2874A6"
          stroke-width="3"/>

    <polygon points="175,160 162,153 162,167"
             fill="#2874A6"/>

    <!-- Weight -->
    <text x="110" y="140"
          font-size="23"
          fill="#8E44AD">
        w
    </text>


    <!-- Summation -->
    <rect x="175" y="115"
          width="80"
          height="90"
          rx="8"
          fill="white"
          stroke="#2C3E50"
          stroke-width="3"/>

    <text x="215" y="175"
          text-anchor="middle"
          font-size="40"
          fill="#2C3E50">
        Σ
    </text>


    <!-- Bias -->
    <line x1="215" y1="285"
          x2="215" y2="205"
          stroke="#E67E22"
          stroke-width="3"/>

    <polygon points="215,205 208,218 222,218"
             fill="#E67E22"/>

    <text x="235" y="265"
          font-size="23"
          fill="#E67E22">
        b
    </text>


    <!-- n -->
    <line x1="255" y1="160"
          x2="355" y2="160"
          stroke="#34495E"
          stroke-width="3"/>

    <polygon points="355,160 342,153 342,167"
             fill="#34495E"/>

    <text x="300" y="140"
          font-size="23"
          fill="#34495E">
        n
    </text>


    <!-- Function -->
    <rect x="355" y="115"
          width="80"
          height="90"
          rx="8"
          fill="#EAF8F0"
          stroke="#27AE60"
          stroke-width="3"/>

    <text x="395" y="175"
          text-anchor="middle"
          font-size="38"
          fill="#27AE60">
        f
    </text>


    <!-- Output -->
    <line x1="435" y1="160"
          x2="525" y2="160"
          stroke="#C0392B"
          stroke-width="3"/>

    <polygon points="525,160 512,153 512,167"
             fill="#C0392B"/>

    <text id="output"
          x="555"
          y="170"
          text-anchor="middle"
          font-size="25"
          font-weight="bold"
          fill="#C0392B">
        a
    </text>


    <!-- Equation -->
    <text x="300"
          y="325"
          text-anchor="middle"
          font-size="22"
          fill="#17202A">
        a = f(wp + b) = f(n)
    </text>

</svg>

</div>


<!-- ================= CONTROLS ================= -->

<div class="controls">

<h3 style="color:#2C3E50;">
    Neuron Inputs
</h3>


<div class="control">

<label style="color:#2874A6;">
    Input p
</label>

<input id="p"
       type="range"
       min="-5"
       max="5"
       step="0.1"
       value="1">

<span id="p-value" class="value">
1.0
</span>

</div>


<div class="control">

<label style="color:#8E44AD;">
    Weight w
</label>

<input id="w"
       type="range"
       min="-5"
       max="5"
       step="0.1"
       value="1">

<span id="w-value" class="value">
1.0
</span>

</div>


<div class="control">

<label style="color:#E67E22;">
    Bias b
</label>

<input id="b"
       type="range"
       min="-5"
       max="5"
       step="0.1"
       value="0">

<span id="b-value" class="value">
0.0
</span>

</div>


<div class="calculation">

<div>
    <b>n = wp + b</b>
</div>

<div id="calculation">
    n = (1.0)(1.0) + 0.0 = 1.0
</div>

<div>
    <b id="result">
        a = f(1.0) = 1.0
    </b>
</div>

</div>

</div>

</div>

</div>


<script>

function updateNeuron() {

    let p = parseFloat(document.getElementById("p").value);
    let w = parseFloat(document.getElementById("w").value);
    let b = parseFloat(document.getElementById("b").value);

    // Net input
    let n = w * p + b;

    // Simple transfer function
    let a = n;


    // Display input values
    document.getElementById("p-value").innerText =
        p.toFixed(1);

    document.getElementById("w-value").innerText =
        w.toFixed(1);

    document.getElementById("b-value").innerText =
        b.toFixed(1);


    // Display calculation
    document.getElementById("calculation").innerText =
        "n = (" + w.toFixed(1) + ")(" +
        p.toFixed(1) + ") + " +
        b.toFixed(1) +
        " = " + n.toFixed(2);


    // Display output
    document.getElementById("result").innerText =
        "a = f(" + n.toFixed(2) +
        ") = " + a.toFixed(2);

    document.getElementById("output").textContent =
        "a = " + a.toFixed(2);
}


// Update when sliders move
document.getElementById("p")
    .addEventListener("input", updateNeuron);

document.getElementById("w")
    .addEventListener("input", updateNeuron);

document.getElementById("b")
    .addEventListener("input", updateNeuron);


// Initial calculation
updateNeuron();

</script>
"""))
# Out:
# <style>
# .neuron-box {
#     font-family: Arial, sans-serif;
#     max-width: 1000px;
#     margin: auto;
#     padding: 25px;
#     background: #f5f7fa;
#     border-radius: 15px;
# }
#
# .neuron-title {
#     text-align: center;
#     font-size: 28px;
#     font-weight: bold;
#     color: #17202a;
#     margin-bottom: 25px;
# }
#
# .neuron-layout {
#     display: flex;
#     gap: 30px;
#     align-items: center;
#     justify-content: center;
# }
#
# .diagram {
#     background: white;
#     border-radius: 15px;
#     padding: 10px;
#     box-shadow: 0 3px 12px #cccccc;
# }
#
# .controls {
#     background: white;
#     padding: 20px;
#     border-radius: 15px;
#     box-shadow: 0 3px 12px #cccccc;
#     width: 300px;
# }
#
# .control {
#     margin: 18px 0;
# }
#
# .control label {
#     display: block;
#     font-weight: bold;
#     margin-bottom: 6px;
# }
#
# .control input[type="range"] {
#     width: 200px;
# }
#
# .value {
#     display: inline-block;
#     width: 55px;
#     text-align: center;
#     font-weight: bold;
# }
#
# .calculation {
#     margin-top: 20px;
#     padding: 15px;
#     background: #eef2f7;
#     border-radius: 10px;
#     line-height: 1.8;
#     font-size: 17px;
# }
# </style>
#
#
# <div class="neuron-box">
#
# <div class="neuron-title">
#     Single-Input Neuron
# </div>
#
# <div class="neuron-layout">
#
# <!-- ================= DIAGRAM ================= -->
#
# <div class="diagram">
#
# <svg width="600" height="350" viewBox="0 0 600 350">
#
#     <!-- Input -->
#     <circle cx="55" cy="160" r="8"
#             fill="#2874A6"/>
#
#     <text x="30" y="125"
#           font-size="18"
#           font-weight="bold"
#           fill="#2874A6">
#         Input
#     </text>
#
#     <text x="42" y="195"
#           font-size="25"
#           fill="#2874A6">
#         p
#     </text>
#
#     <!-- Arrow p -->
#     <line x1="65" y1="160"
#           x2="175" y2="160"
#           stroke="#2874A6"
#           stroke-width="3"/>
#
#     <polygon points="175,160 162,153 162,167"
#              fill="#2874A6"/>
#
#     <!-- Weight -->
#     <text x="110" y="140"
#           font-size="23"
#           fill="#8E44AD">
#         w
#     </text>
#
#
#     <!-- Summation -->
#     <rect x="175" y="115"
#           width="80"
#           height="90"
#           rx="8"
#           fill="white"
#           stroke="#2C3E50"
#           stroke-width="3"/>
#
#     <text x="215" y="175"
#           text-anchor="middle"
#           font-size="40"
#           fill="#2C3E50">
#         Σ
#     </text>
#
#
#     <!-- Bias -->
#     <line x1="215" y1="285"
#           x2="215" y2="205"
#           stroke="#E67E22"
#           stroke-width="3"/>
#
#     <polygon points="215,205 208,218 222,218"
#              fill="#E67E22"/>
#
#     <text x="235" y="265"
#           font-size="23"
#           fill="#E67E22">
#         b
#     </text>
#
#
#     <!-- n -->
#     <line x1="255" y1="160"
#           x2="355" y2="160"
#           stroke="#34495E"
#           stroke-width="3"/>
#
#     <polygon points="355,160 342,153 342,167"
#              fill="#34495E"/>
#
#     <text x="300" y="140"
#           font-size="23"
#           fill="#34495E">
#         n
#     </text>
#
#
#     <!-- Function -->
#     <rect x="355" y="115"
#           width="80"
#           height="90"
#           rx="8"
#           fill="#EAF8F0"
#           stroke="#27AE60"
#           stroke-width="3"/>
#
#     <text x="395" y="175"
#           text-anchor="middle"
#           font-size="38"
#           fill="#27AE60">
#         f
#     </text>
#
#
#     <!-- Output -->
#     <line x1="435" y1="160"
#           x2="525" y2="160"
#           stroke="#C0392B"
#           stroke-width="3"/>
#
#     <polygon points="525,160 512,153 512,167"
#              fill="#C0392B"/>
#
#     <text id="output"
#           x="555"
#           y="170"
#           text-anchor="middle"
#           font-size="25"
#           font-weight="bold"
#           fill="#C0392B">
#         a
#     </text>
#
#
#     <!-- Equation -->
#     <text x="300"
#           y="325"
#           text-anchor="middle"
#           font-size="22"
#           fill="#17202A">
#         a = f(wp + b) = f(n)
#     </text>
#
# </svg>
#
# </div>
#
#
# <!-- ================= CONTROLS ================= -->
#
# <div class="controls">
#
# <h3 style="color:#2C3E50;">
#     Neuron Inputs
# </h3>
#
#
# <div class="control">
#
# <label style="color:#2874A6;">
#     Input p
# </label>
#
# <input id="p"
#        type="range"
#        min="-5"
#        max="5"
#        step="0.1"
#        value="1">
#
# <span id="p-value" class="value">
# 1.0
# </span>
#
# </div>
#
#
# <div class="control">
#
# <label style="color:#8E44AD;">
#     Weight w
# </label>
#
# <input id="w"
#        type="range"
#        min="-5"
#        max="5"
#        step="0.1"
#        value="1">
#
# <span id="w-value" class="value">
# 1.0
# </span>
#
# </div>
#
#
# <div class="control">
#
# <label style="color:#E67E22;">
#     Bias b
# </label>
#
# <input id="b"
#        type="range"
#        min="-5"
#        max="5"
#        step="0.1"
#        value="0">
#
# <span id="b-value" class="value">
# 0.0
# </span>
#
# </div>
#
#
# <div class="calculation">
#
# <div>
#     <b>n = wp + b</b>
# </div>
#
# <div id="calculation">
#     n = (1.0)(1.0) + 0.0 = 1.0
# </div>
#
# <div>
#     <b id="result">
#         a = f(1.0) = 1.0
#     </b>
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
#
# <script>
#
# function updateNeuron() {
#
#     let p = parseFloat(document.getElementById("p").value);
#     let w = parseFloat(document.getElementById("w").value);
#     let b = parseFloat(document.getElementById("b").value);
#
#     // Net input
#     let n = w * p + b;
#
#     // Simple transfer function
#     let a = n;
#
#
#     // Display input values
#     document.getElementById("p-value").innerText =
#         p.toFixed(1);
#
#     document.getElementById("w-value").innerText =
#         w.toFixed(1);
#
#     document.getElementById("b-value").innerText =
#         b.toFixed(1);
#
#
#     // Display calculation
#     document.getElementById("calculation").innerText =
#         "n = (" + w.toFixed(1) + ")(" +
#         p.toFixed(1) + ") + " +
#         b.toFixed(1) +
#         " = " + n.toFixed(2);
#
#
#     // Display output
#     document.getElementById("result").innerText =
#         "a = f(" + n.toFixed(2) +
#         ") = " + a.toFixed(2);
#
#     document.getElementById("output").textContent =
#         "a = " + a.toFixed(2);
# }
#
#
# // Update when sliders move
# document.getElementById("p")
#     .addEventListener("input", updateNeuron);
#
# document.getElementById("w")
#     .addEventListener("input", updateNeuron);
#
# document.getElementById("b")
#     .addEventListener("input", updateNeuron);
#
#
# // Initial calculation
# updateNeuron();
#
# </script>

# %% [markdown]
# 8. The actual output depends on the particular transfer function that is chosen.
# 9. We will discuss transfer function in the next section
# 10. The bias is much like a weight, except that it has a constant input of 1.
# 11. However, if you do not want to have a bias in a particular neuron, it can be omitted. We will see examples of this in Chapter 3, 7 and 16
# 12. **Note :** *w* and *b* are both *adjustable* scalar parameters of the neurons.
# 13. Typically the *Transfer function* is chosen by the designer and then the parameters *w* and *b* will be adjusted by some learning rule
# 14. So that the neuron input/output relationship meets some specific goal (see Chapter 4 for an introduction to learning rules).
# 15. As described in the following section, we have different transfer functions for different purposes.
